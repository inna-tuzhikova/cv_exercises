# %%
import cv2
import numpy as np

from matplotlib import pyplot as plt

# %%
# Read image
im = cv2.imread("bag_1.jpg", cv2.IMREAD_GRAYSCALE)
 
# Set up the detector with default parameters.
detector = cv2.SimpleBlobDetector_create()
 
# Detect blobs.
keypoints = detector.detect(im)
 
# Draw detected blobs as red circles.
# cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS ensures the size of the circle corresponds to the size of blob
# im_with_keypoints = cv2.drawKeypoints(im, keypoints, np.array([]), (0,0,255), 
#                                       cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
 
im2 = im.copy()
for marker in keypoints:
    im2 = cv2.drawMarker(im2, tuple(int(i) for i in marker.pt), color=(0, 0, 255))
plt.imshow(im2), plt.show()
    
# Show keypoints
# cv2.imshow("Keypoints", im2)
# cv2.waitKey(0)
# Out:
# (<matplotlib.image.AxesImage at 0x7f6533f1e048>, None)
